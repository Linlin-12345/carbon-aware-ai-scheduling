# %% [markdown]
# # Notebook 1: Data Preparation
#
# **Project:** How Time and Location Choices Change the Carbon Footprint of AI Training
# **Data:** EIA Form 930 BALANCE — Jan–Dec 2025
#
# This notebook:
# 1. Loads the raw EIA Form 930 CSV files
# 2. Cleans and merges the data
# 3. Constructs the carbon exposure proxy and lag features
# 4. Outputs `data/processed/analysis_dataset.csv` for use in subsequent notebooks
#
# **Data source:** https://www.eia.gov/electricity/gridmonitor/
# Download `EIA930_BALANCE_2025_Jan_Jun.csv` and `EIA930_BALANCE_2025_Jul_Dec.csv` and place in `data/raw/`

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

RAW_DIR = Path('../data/raw/')
PROCESSED_DIR = Path('../data/processed/')
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

print('Setup complete.')

# %%
# Load and concatenate both half-year files
files = sorted(RAW_DIR.glob('EIA930_BALANCE_2025_*.csv'))
print(f'Found {len(files)} raw files: {[f.name for f in files]}')

dfs = [pd.read_csv(f, low_memory=False) for f in files]
df_raw = pd.concat(dfs, ignore_index=True)
print(f'Combined: {df_raw.shape[0]:,} rows × {df_raw.shape[1]} columns')

# %%
# --- Add your data cleaning and feature engineering code here ---
# See src/carbon_proxy.py for utility functions
import sys
sys.path.insert(0, '../src')
from carbon_proxy import build_carbon_proxy, add_time_features, add_lag_features

# Build proxy, time features, lag features
# df = build_carbon_proxy(df_raw)
# df = add_time_features(df)
# df = add_lag_features(df)

# Save
# df.to_csv(PROCESSED_DIR / 'analysis_dataset.csv', index=False)
# print(f'Saved: {len(df):,} rows → data/processed/analysis_dataset.csv')
